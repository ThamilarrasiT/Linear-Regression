# %% [markdown]
# <a href="https://colab.research.google.com/github/ThamilarrasiT/Linear-Regression/blob/main/LR_with_library1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sn

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv("/content/Salary_dataset.csv")
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
x=df[['YearsExperience']]
y=df['Salary']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2529)

# %%
print("Shapes:")
print("x_train:", x_train.shape)
print("x_test:", x_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# Shapes:
# x_train: (21, 1)
# x_test: (9, 1)
# y_train: (21,)
# y_test: (9,)

# %%
a=LinearRegression()
a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Intercept(C)=",a.intercept_)
print("Slope(m)=",a.coef_[0])
# Out:
# Intercept(C)= 24306.39319686479
# Slope(m)= 9441.469351647514

# %%
y_pred=a.predict(x_test)
print("Predicted =",y_pred)
# Out:
# Predicted = [ 37524.45028917  75290.32769576  73402.03382543 102670.58881554
#  110223.76429686  44133.47883532  89452.53172323 114944.49897268
#   39412.7441595 ]

# %%
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MAPE=",mean_absolute_percentage_error(y_test,y_pred))
print("MSE=",mean_squared_error(y_test,y_pred))
# Out:
# MAE: 5137.291513414337
# MAPE= 0.0706655184547393
# MSE= 38750002.34819779

# %%
plt.scatter(x,y,color="blue",label="Actual data")
plt.plot(x,a.predict(x),color="red",label="Regression line")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.title("salary Prediction")
plt.legend()
plt.show()
